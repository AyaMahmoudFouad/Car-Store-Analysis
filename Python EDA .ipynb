# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("Carscleaned1.csv", encoding='ISO-8859-1')

# %%
df.head()
# Out:
#    year   make                model Car trim level   body transmission  \
# 0  2015    Kia              Sorento             LX    SUV    automatic
# 1  2015    Kia              Sorento             LX    SUV    automatic
# 2  2014    BMW             3 Series     328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60             T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe           650i  Sedan    automatic
#
#        Vehicle_id_no state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca          5     16639  white    black
# 1  5xyktca69fg561319    ca          5      9393  white    beige
# 2  wba3c1c51ek116351    ca         45      1331   gray    black
# 3  yv1612tb4f1310987    ca         41     14282  white    black
# 4  wba6b2c57ed129731    ca         43      2641   gray    black
#
#                                    seller    mmr  sellingprice    saledate
# 0                 kia motors america  inc  20500         21500  12/16/2014
# ...

# %%
df.tail()
# Out:
#         year    make     model Car trim level       body transmission  \
# 465851  2011     BMW  5 Series           528i      Sedan    automatic
# 465852  2012     Ram      2500    Power Wagon   Crew Cab    automatic
# 465853  2012     BMW        X5      xDrive35d        SUV    automatic
# 465854  2015  Nissan    Altima          2.5 S      sedan    automatic
# 465855  2014    Ford     F-150            XLT  SuperCrew    automatic
#
#             Vehicle_id_no state  condition  odometer  color interior  \
# 465851  wbafr1c53bc744672    fl         39     66403  white    brown
# 465852  3c6td5et6cg112407    wa          5     54393  white    black
# 465853  5uxzw0c58cl668465    ca         48     50561  black    black
# 465854  1n4al3ap0fc216050    ga         38     16658  white    black
# 465855  1ftfw1et2eke87277    ca         34     15008   gray     gray
#
#                                                    seller    mmr  \
# ...

# %%
df.shape
# Out:
# (465856, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465856 entries, 0 to 465855
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   year            465856 non-null  int64
#  1   make            465856 non-null  object
#  2   model           465768 non-null  object
#  3   Car trim level  465856 non-null  object
#  4   body            465856 non-null  object
#  5   transmission    465856 non-null  object
#  6   Vehicle_id_no   465856 non-null  object
#  7   state           465856 non-null  object
#  8   condition       465856 non-null  int64
#  9   odometer        465856 non-null  int64
#  10  color           465856 non-null  object
#  11  interior        465856 non-null  object
#  12  seller          465856 non-null  object
#  13  mmr             465856 non-null  int64
#  14  sellingprice    465856 non-null  int64
#  15  saledate        465856 non-null  object
# dtypes: int64(5), object(11)
# ...

# %%
df.describe()
# Out:
#                 year      condition       odometer            mmr  \
# count  465856.000000  465856.000000  465856.000000  465856.000000
# mean     2010.217565      30.767261   66643.220029   13843.730627
# std         3.828143      13.304447   52060.125277    9565.598447
# min      1990.000000       1.000000       1.000000      25.000000
# 25%      2008.000000      24.000000   28021.000000    7425.000000
# 50%      2012.000000      35.000000   50849.500000   12300.000000
# 75%      2013.000000      42.000000   96604.250000   18300.000000
# max      2015.000000      49.000000  999999.000000  182000.000000
#
#         sellingprice
# count  465856.000000
# mean    13694.933634
# std      9643.726466
# min         1.000000
# 25%      7200.000000
# 50%     12200.000000
# 75%     18200.000000
# max    230000.000000

# %%
df.isnull().sum()
# Out:
# year               0
# make               0
# model             88
# Car trim level     0
# body               0
# transmission       0
# Vehicle_id_no      0
# state              0
# condition          0
# odometer           0
# color              0
# interior           0
# seller             0
# mmr                0
# sellingprice       0
# saledate           0
# dtype: int64

# %%
data = df.drop_duplicates(subset ="Vehicle_id_no",)
data
# Out:
#         year    make                model Car trim level       body  \
# 0       2015     Kia              Sorento             LX        SUV
# 1       2015     Kia              Sorento             LX        SUV
# 2       2014     BMW             3 Series     328i SULEV      Sedan
# 3       2015   Volvo                  S60             T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe           650i      Sedan
# ...      ...     ...                  ...            ...        ...
# 465851  2011     BMW             5 Series           528i      Sedan
# 465852  2012     Ram                 2500    Power Wagon   Crew Cab
# 465853  2012     BMW                   X5      xDrive35d        SUV
# 465854  2015  Nissan               Altima          2.5 S      sedan
# 465855  2014    Ford                F-150            XLT  SuperCrew
#
#        transmission      Vehicle_id_no state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca          5     16639  white
# ...
